# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
matches = pd.read_csv('IPL Matches 2008-2020.csv')
balls = pd.read_csv('IPL Ball-by-Ball 2008-2020.csv')
print('Priyatma is ready!')
# Out:
# Priyatma is ready!

# %%
data = pd.merge(left=matches, right=balls, on='id', how='right')
data.shape
# Out:
# (193468, 34)

# %%
data = data.replace(to_replace='Rising Pune Supergiant',value='Rising Pune Supergiants')
data = data.replace(to_replace='Royal Challengers Bangalore',value='RCB')
data = data.replace(to_replace='Kolkata Knight Riders',value='KKR')
data = data.replace(to_replace='Mumbai Indians',value='MI')
data = data.replace(to_replace='Rajasthan Royals',value='RR')
data = data.replace(to_replace='Kings XI Punjab',value='KXIP')
data = data.replace(to_replace='Delhi Daredevils',value='DD')
data = data.replace(to_replace='Deccan Chargers',value='SRH')
data = data.replace(to_replace='Chennai Super Kings',value='CSK')
data = data.replace(to_replace='Pune Warriors India',value='Pune')
data = data.replace(to_replace='Kochi Tuskers Kerala',value='KTK')
data = data.replace(to_replace='Sunrisers Hyderabad',value='SRH')
data = data.replace(to_replace='Rising Pune Supergiants',value='Pune')
data = data.replace(to_replace='Gujarat Lions',value='GL')
data = data.replace(to_replace='Delhi Capitals',value='DC')
data = data.replace(to_replace='Pune Warriors',value='Pune')

data.head(1)
# Out:
#        id       city        date player_of_match                  venue  \
# 0  335982  Bangalore  2008-04-18     BB McCullum  M Chinnaswamy Stadium
#
#    neutral_venue team1 team2 toss_winner toss_decision  ... extra_runs  \
# 0              0   RCB   KKR         RCB         field  ...          0
#
#   total_runs  non_boundary is_wicket dismissal_kind player_dismissed fielder  \
# 0          1             0         0   Not a wicket              NaN     NaN
#
#    extras_type  batting_team  bowling_team
# 0          NaN           KKR           RCB
#
# [1 rows x 34 columns]

# %%
sorted(data['batting_team'].unique().tolist())
# Out:
# ['CSK',
#  'DC',
#  'DD',
#  'GL',
#  'KKR',
#  'KTK',
#  'KXIP',
#  'MI',
#  'PWI',
#  'RCB',
#  'RPSG',
#  'RR',
#  'SRH']

# %%
data.isnull().sum()
# Out:
# id                       0
# city                  3139
# date                     0
# player_of_match        372
# venue                    0
# neutral_venue            0
# team1                    0
# team2                    0
# toss_winner              0
# toss_decision            0
# winner                 372
# result                 372
# result_margin         3597
# eliminator             372
# method              190260
# umpire1                  0
# umpire2                  0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# dtype: int64

# %%
balls['dismissal_kind'].fillna('Not a wicket', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 193468 entries, 0 to 193467
# Data columns (total 34 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                193468 non-null  int64
#  1   city              190329 non-null  object
#  2   date              193468 non-null  object
#  3   player_of_match   193096 non-null  object
#  4   venue             193468 non-null  object
#  5   neutral_venue     193468 non-null  int64
#  6   team1             193468 non-null  object
#  7   team2             193468 non-null  object
#  8   toss_winner       193468 non-null  object
#  9   toss_decision     193468 non-null  object
#  10  winner            193096 non-null  object
#  11  result            193096 non-null  object
#  12  result_margin     189871 non-null  float64
#  13  eliminator        193096 non-null  object
#  14  method            3208 non-null    object
#  15  umpire1           193468 non-null  object
#  16  umpire2           193468 non-null  object
#  17  inning            193468 non-null  int64
#  18  over              193468 non-null  int64
#  19  ball              193468 non-null  int64
#  20  batsman           193468 non-null  object
#  21  non_striker       193468 non-null  object
#  22  bowler            193468 non-null  object
#  23  batsman_runs      193468 non-null  int64
#  24  extra_runs        193468 non-null  int64
#  25  total_runs        193468 non-null  int64
#  26  non_boundary      193468 non-null  int64
#  27  is_wicket         193468 non-null  int64
#  28  dismissal_kind    9495 non-null    object
#  29  player_dismissed  9495 non-null    object
#  30  fielder           6784 non-null    object
#  31  extras_type       10233 non-null   object
#  32  batting_team      193468 non-null  object
#  33  bowling_team      193277 non-null  object
# dtypes: float64(1), int64(10), object(23)
# memory usage: 51.7+ MB

# %%
data['date'] = pd.to_datetime(data['date'])
data['year'] = pd.DatetimeIndex(data['date']).year

# %%
data.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'inning',
#        'over', 'ball', 'batsman', 'non_striker', 'bowler', 'batsman_runs',
#        'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team', 'year'],
#       dtype='object')

# %%
data.to_csv('ipl-done.csv', index = False)

# %%
data.head()
# Out:
#        id       city       date player_of_match                  venue  \
# 0  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 1  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 2  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 3  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 4  335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
#
#    neutral_venue team1 team2 toss_winner toss_decision  ... total_runs  \
# 0              0   RCB   KKR         RCB         field  ...          1
# 1              0   RCB   KKR         RCB         field  ...          1
# 2              0   RCB   KKR         RCB         field  ...          0
# 3              0   RCB   KKR         RCB         field  ...          1
# 4              0   RCB   KKR         RCB         field  ...          1
#
#   non_boundary  is_wicket dismissal_kind player_dismissed fielder extras_type  \
# 0            0          0            NaN              NaN     NaN         NaN
# 1            0          0            NaN              NaN     NaN         NaN
# 2            0          0            NaN              NaN     NaN         NaN
# 3            0          0            NaN              NaN     NaN         NaN
# 4            0          0            NaN              NaN     NaN         NaN
#
#    batting_team  bowling_team  year
# 0           KKR           RCB  2008
# 1           KKR           RCB  2008
# 2           KKR           RCB  2008
# 3           KKR           RCB  2008
# 4           KKR           RCB  2008
#
# [5 rows x 35 columns]

# %%
wickets_by_year = data.groupby(by='year').sum()['is_wicket']
wickets_by_year = pd.DataFrame(wickets_by_year)
wickets_by_year.reset_index(inplace=True)
wickets_by_year
# Out:
#     year  is_wicket
# 0   2008        690
# 1   2009        697
# 2   2010        722
# 3   2011        813
# 4   2012        858
# 5   2013        910
# 6   2014        672
# 7   2015        687
# 8   2016        666
# 9   2017        709
# 10  2018        722
# 11  2019        681
# 12  2020        668

# %%
sns.lineplot(data=wickets_by_year, x='year', y='is_wicket')
plt.title('Wickets Taken over the years')
plt.show()

# %%
runs_by_year = data.groupby(by='year').sum()['total_runs']
runs_by_year = pd.DataFrame(runs_by_year)
runs_by_year.reset_index(inplace=True)

# %%
sns.lineplot(data=runs_by_year, x='year', y='total_runs')
plt.title('Runs over the Years')
plt.show()

# %%
wickets_by_team = data.groupby(by='bowling_team').sum()['is_wicket']
wickets_by_team = pd.DataFrame(wickets_by_team)
wickets_by_team.reset_index(inplace=True)

# %%
sns.lineplot(data=wickets_by_team, x='bowling_team', y='is_wicket')
plt.title('Wickets Taken by the Teams')
plt.xticks(rotation=90)
plt.show()

# %%
runs_by_team = data.groupby(by='batting_team').sum()['total_runs']
runs_by_team = pd.DataFrame(runs_by_team)
runs_by_team.reset_index(inplace=True)

# %%
sns.lineplot(data=runs_by_team, x='batting_team', y='total_runs')
plt.title('Runs scored by the Teams')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,112))
sns.countplot(y=balls[balls['dismissal_kind'] != 'Not a wicket']['bowler'],
              order=balls[balls['dismissal_kind'] != 'Not a wicket']['bowler'].value_counts().index)
plt.title('Most wicket taking bowler!')
plt.show()

# %%
data.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'inning',
#        'over', 'ball', 'batsman', 'non_striker', 'bowler', 'batsman_runs',
#        'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team', 'year'],
#       dtype='object')

# %%
plt.figure(figsize=(15,112))
sns.countplot(y=balls[balls['batsman_runs'] != 'Not a wicket']['batsman'],
              order=balls[balls['batsman_runs'] != 'Not a wicket']['batsman'].value_counts().index)
plt.title('Most Runs by a player!')
plt.show()

# %%
plt.figure(figsize=(15,112))
sns.countplot(y=matches[matches['id'] != '0']['player_of_match'],
              order=matches[matches['id'] != '0']['player_of_match'].value_counts().index)
plt.title('Most Player of the match!')
plt.show()

# %%
sns.countplot(x=balls[balls['dismissal_kind'] != 'Not a wicket']['dismissal_kind'],
              order=balls[balls['dismissal_kind'] != 'Not a wicket']['dismissal_kind'].value_counts().index)
plt.title('How are the players being dismissed?')
plt.xticks(rotation=90)
plt.show()

# %%
data['city'].fillna('Dubai',inplace = True)
data.isnull().sum()
# Out:
# id                       0
# city                     0
# date                     0
# player_of_match        372
# venue                    0
# neutral_venue            0
# team1                    0
# team2                    0
# toss_winner              0
# toss_decision            0
# winner                 372
# result                 372
# result_margin         3597
# eliminator             372
# method              190260
# umpire1                  0
# umpire2                  0
# inning                   0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# non_boundary             0
# is_wicket                0
# dismissal_kind      183973
# player_dismissed    183973
# fielder             186684
# extras_type         183235
# batting_team             0
# bowling_team           191
# year                     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2', 'inning',
#        'over', 'ball', 'batsman', 'non_striker', 'bowler', 'batsman_runs',
#        'extra_runs', 'total_runs', 'non_boundary', 'is_wicket',
#        'dismissal_kind', 'player_dismissed', 'fielder', 'extras_type',
#        'batting_team', 'bowling_team', 'year'],
#       dtype='object')

# %%
bat = sorted(data['batsman'].unique().tolist())
bat2 = sorted(data['non_striker'].unique().tolist())
bowl = sorted(data['bowler'].unique().tolist())
import itertools
player = itertools.chain(bat,bat2,bowl)
players = list(player)
players = [*set(players)]

# %%
matches = matches.replace(to_replace='Rising Pune Supergiant',value='Rising Pune Supergiants')
matches = matches.replace(to_replace='Royal Challengers Bangalore',value='RCB')
matches = matches.replace(to_replace='Kolkata Knight Riders',value='KKR')
matches = matches.replace(to_replace='Mumbai Indians',value='MI')
matches = matches.replace(to_replace='Rajasthan Royals',value='RR')
matches = matches.replace(to_replace='Kings XI Punjab',value='KXIP')
matches = matches.replace(to_replace='Delhi Daredevils',value='DD')
matches = matches.replace(to_replace='Deccan Chargers',value='SRH')
matches = matches.replace(to_replace='Chennai Super Kings',value='CSK')
matches = matches.replace(to_replace='Pune Warriors India',value='Pune')
matches = matches.replace(to_replace='Kochi Tuskers Kerala',value='KTK')
matches = matches.replace(to_replace='Sunrisers Hyderabad',value='SRH')
matches = matches.replace(to_replace='Rising Pune Supergiants',value='Pune')
matches = matches.replace(to_replace='Gujarat Lions',value='GL')
matches = matches.replace(to_replace='Delhi Capitals',value='DC')
matches = matches.replace(to_replace='Pune Warriors',value='Pune')
matches[['winner']].groupby('winner')['winner'].count().sort_values(ascending=False)
#matches.head(3)
# Out:
# winner
# MI      120
# CSK     106
# KKR      99
# SRH      95
# RCB      91
# KXIP     88
# DC       86
# RR       81
# RPSG     15
# GL       13
# PWI      12
# KTK       6
# Name: winner, dtype: int64

# %%
matches.head(2)
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
#
#                                         venue  neutral_venue team1 team2  \
# 0                       M Chinnaswamy Stadium              0   RCB   KKR
# 1  Punjab Cricket Association Stadium, Mohali              0  KXIP   CSK
#
#   toss_winner toss_decision winner result  result_margin eliminator method  \
# 0         RCB         field    KKR   runs          140.0          N    NaN
# 1         CSK           bat    CSK   runs           33.0          N    NaN
#
#      umpire1      umpire2
# 0  Asad Rauf  RE Koertzen
# 1  MR Benson   SL Shastri

# %%
matches[['city']].groupby('city')['city'].count().sort_values(ascending=False).head(10)
# Out:
# city
# Mumbai        101
# Kolkata        77
# Delhi          74
# Bangalore      65
# Hyderabad      64
# Chennai        57
# Chandigarh     56
# Jaipur         47
# Pune           38
# Abu Dhabi      29
# Name: city, dtype: int64

# %%
matches.to_csv('matches_done.csv', index = False)
